# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from urllib.request import urlopen
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
seasons = [1,2,3,4,8,26,49]
categories = [104,100,23,102,21,22,103,138,139,132,101,28]
category_name = ['Super Raids', 'Super 10s','Successful Tackles' ,'Total points','successful raids','Raid points','Tackle Points'
               ,'Avg Raid points', 'Avg tackle points','Do or die raid points','High 5s','Super tackles']

# %%
## Data for all seasons, all categories
data = pd.DataFrame()

tmp_category = 0
for index,category in enumerate(categories):
    data_for_seasons = pd.DataFrame()
    print(category_name[index])
    for s in seasons:
        jsonurl = urlopen("https://www.prokabaddi.com/sifeeds/kabaddi/static/json/1_{0}_{1}_stats.json".format(s,category))

        data_json = json.load(jsonurl)
        
        df = pd.DataFrame(data_json['data'])
        df = df.rename(columns={'position_id':'position_id'.format(s), 'position_name':'position_name'.format(s), 
                   'team_id':'team_id'.format(s),
                   'team_name':'team_name'.format(s),
                    'rank':'rank'.format(s),
                    'match_played':'match_played'.format(s),
                  'value':'value'.format(s)})
       
        if(data_for_seasons.shape[0] == 0):
            data_for_seasons = df
        
        else:    
            data_for_seasons = pd.concat([df,data_for_seasons],ignore_index=True)
        if('season_id' in data_for_seasons.columns):
            data_for_seasons['season_id'] = data_for_seasons['season_id'].fillna(s)
        else:
            data_for_seasons['season_id'] = s
            
    data_for_seasons['category'] = category
    data_for_seasons['category_name'] = category_name[index]
    
    tmp_category = category
    if(data.shape[0] == 0):
        data = data_for_seasons
    else:  
        #print(data_for_seasons.head())
        #print(data.head())
        #print(set(data_for_seasons.columns) ^ set(data.columns))
        
        data = pd.concat([data,data_for_seasons],ignore_index=True)
# Out:
# Super Raids
# Super 10s
# Successful Tackles
# Total points
# successful raids
# Raid points
# Tackle Points
# Avg Raid points
# Avg tackle points
# Do or die raid points
# High 5s
# Super tackles

# %%
data.shape
# Out:
# (6833, 17)

# %%
data
# Out:
#       category  category_name  match played  match_played player  player_id  \
# 0          104    Super Raids           NaN            17    NaN        197
# 1          104    Super Raids           NaN            13    NaN        366
# 2          104    Super Raids           NaN            17    NaN        143
# 3          104    Super Raids           NaN            17    NaN        318
# 4          104    Super Raids           NaN            16    NaN       2488
# 5          104    Super Raids           NaN            15    NaN       2661
# 6          104    Super Raids           NaN            11    NaN       2485
# 7          104    Super Raids           NaN            15    NaN         36
# 8          104    Super Raids           NaN            17    NaN        484
# 9          104    Super Raids           NaN            17    NaN        219
# 10         104    Super Raids           NaN            13    NaN        261
# 11         104    Super Raids           NaN            16    NaN         41
# 12         104    Super Raids           NaN            12    NaN         94
# 13         104    Super Raids           NaN            13    NaN         26
# 14         104    Super Raids           NaN            10    NaN        111
# 15         104    Super Raids           NaN             6    NaN       2498
# 16         104    Super Raids           NaN            16    NaN       2296
# 17         104    Super Raids           NaN            17    NaN        326
# 18         104    Super Raids           NaN            18    NaN        763
# 19         104    Super Raids           NaN            15    NaN       2024
# 20         104    Super Raids           NaN            16    NaN       2026
# 21         104    Super Raids           NaN            14    NaN       2028
# 22         104    Super Raids           NaN             8    NaN       2290
# 23         104    Super Raids           NaN            12    NaN        791
# 24         104    Super Raids           NaN             6    NaN       2298
# 25         104    Super Raids           NaN             4    NaN       2325
# 26         104    Super Raids           NaN            13    NaN       2357
# 27         104    Super Raids           NaN             3    NaN       2507
# 28         104    Super Raids           NaN            14    NaN       2508
# 29         104    Super Raids           NaN            10    NaN       2494
# ...        ...            ...           ...           ...    ...        ...
# 6803        28  Super tackles          14.0            14    NaN         98
# 6804        28  Super tackles          14.0            14    NaN        118
# 6805        28  Super tackles          10.0            10    NaN        160
# 6806        28  Super tackles           6.0             6    NaN        164
# 6807        28  Super tackles          10.0            10    NaN        165
# 6808        28  Super tackles           8.0             8    NaN        166
# 6809        28  Super tackles          12.0            12    NaN        161
# 6810        28  Super tackles          12.0            12    NaN        159
# 6811        28  Super tackles           8.0             8    NaN        151
# 6812        28  Super tackles          16.0            16    NaN        123
# 6813        28  Super tackles          14.0            14    NaN        107
# 6814        28  Super tackles          13.0            13    NaN        108
# 6815        28  Super tackles          16.0            16    NaN        143
# 6816        28  Super tackles           8.0             8    NaN         77
# 6817        28  Super tackles          14.0            14    NaN         81
# 6818        28  Super tackles          14.0            14    NaN         84
# 6819        28  Super tackles          15.0            15    NaN         85
# 6820        28  Super tackles          16.0            16    NaN         86
# 6821        28  Super tackles           9.0             9    NaN         89
# 6822        28  Super tackles          15.0            15    NaN         96
# 6823        28  Super tackles           5.0             5    NaN         97
# 6824        28  Super tackles           5.0             5    NaN         38
# 6825        28  Super tackles          16.0            16    NaN         45
# 6826        28  Super tackles           7.0             7    NaN         46
# 6827        28  Super tackles           2.0             2    NaN          5
# 6828        28  Super tackles           9.0             9    NaN         14
# 6829        28  Super tackles          15.0            15    NaN         52
# 6830        28  Super tackles          14.0            14    NaN         58
# 6831        28  Super tackles           3.0             3    NaN         61
# 6832        28  Super tackles          14.0            14    NaN         72
#
#                       player_name  position_id           position_name rank  \
# 0                  Pardeep Narwal          8.0                  Raider    1
# 1                  Vikash Kandola          8.0                  Raider    2
# 2                  Maninder Singh          8.0                  Raider    2
# 3            Pawan Kumar Sehrawat          8.0                  Raider    2
# 4                           Vinay          8.0                  Raider    2
# 5                   Pankaj Mohite          8.0                  Raider    6
# 6                     Sonu Jaglan          8.0                  Raider    7
# 7                 Chandran Ranjit          8.0                  Raider    7
# 8     Mohammad Esmaeil Nabibakhsh          1.0             All Rounder    7
# 9                    K. Prapanjan          8.0                  Raider    7
# 10                  Rohit Baliyan          8.0                  Raider   11
# 11             Deepak Niwas Hooda          1.0             All Rounder   11
# 12               Rishank Devadiga          8.0                  Raider   11
# 13                    Ajay Thakur          8.0                  Raider   11
# 14                   Sukesh Hegde          8.0                  Raider   11
# 15                   Sushil Gulia          8.0                  Raider   11
# 16                   Naveen Kumar          8.0                  Raider   11
# 17                    Rohit Kumar          8.0                  Raider   11
# 18                        Manjeet          8.0                  Raider   11
# 19                  Arjun Deshwal          8.0                  Raider   11
# 20         Siddharth Sirish Desai          8.0                  Raider   11
# 21                 Abhishek Singh          8.0                  Raider   11
# 22                        Rajnish          8.0                  Raider   23
# 23                    Nitin Rawal          1.0             All Rounder   23
# 24                         Armaan          1.0             All Rounder   23
# 25                          Anand          8.0                  Raider   23
# 26                         Naveen          8.0                  Raider   23
# 27                     Amit Kumar          1.0             All Rounder   23
# 28                 V. Ajith Kumar          8.0                  Raider   23
# 29                  Sachin Narwal          1.0             All Rounder   23
# ...                           ...          ...                     ...  ...
# 6803                Sachin Khambe          3.0   Defender, left corner   15
# 6804               Surjeet Narwal          8.0                  Raider   15
# 6805                    Ran Singh          1.0             All Rounder   15
# 6806               Bajirao Hodage          7.0   Defender, right cover   15
# 6807              Sachin Shingade          4.0    Defender, left cover   24
# 6808               Vijendar Singh          NaN                    None   24
# 6809          Girish Maruti Ernak          3.0   Defender, left corner   24
# 6810              Samarjeet Singh          1.0             All Rounder   24
# 6811                  Vikas Tomar          6.0  Defender, right corner   24
# 6812                  Vishal Mane          7.0   Defender, right cover   24
# 6813             Shrikant Tewthia          1.0             All Rounder   24
# 6814              Shyam Kumar Sah          4.0    Defender, left cover   24
# 6815               Maninder Singh          8.0                  Raider   24
# 6816                Parveen Kumar          7.0   Defender, right cover   24
# 6817              Rahul Chaudhari          8.0                  Raider   24
# 6818         Rajaguru Subramanian          7.0   Defender, right cover   24
# 6819                Rajesh Mondal          8.0                  Raider   24
# 6820                Rajesh Narwal          1.0             All Rounder   24
# 6821                Ram Kumar Sah          4.0    Defender, left cover   24
# 6822                   Rohit Rana          4.0    Defender, left cover   24
# 6823                 Rupesh Tomar          1.0             All Rounder   24
# 6824           Dadaso Balaso Awad          1.0             All Rounder   24
# 6825               Gurpreet Singh          6.0  Defender, right corner   24
# 6826              Gurvinder Singh          8.0                  Raider   24
# 6827         Farhad Kamal Gharibi          3.0   Defender, left corner   24
# 6828                 Tae Deok Eom          1.0             All Rounder   24
# 6829                 Jasvir Singh          8.0                  Raider   24
# 6830              Kashiling Adake          8.0                  Raider   24
# 6831                Kuldeep Singh          3.0   Defender, left corner   24
# 6832               Navneet Gautam          3.0   Defender, left corner   24
#
#       season_id  tackles       team         team_full_name  team_id  \
# 0          49.0      NaN        Pat          Patna Pirates        6
# 1          49.0      NaN         HS       Haryana Steelers       28
# 2          49.0      NaN        Kol        Bengal Warriors        4
# 3          49.0      NaN        Ben        Bengaluru Bulls        1
# 4          49.0      NaN         HS       Haryana Steelers       28
# 5          49.0      NaN        Pun          Puneri Paltan        7
# 6          49.0      NaN        GFG  Gujarat Fortunegiants       31
# 7          49.0      NaN        Del      Dabang Delhi K.C.        2
# 8          49.0      NaN        Kol        Bengal Warriors        4
# 9          49.0      NaN        Kol        Bengal Warriors        4
# 10         49.0      NaN        Mum                U Mumba        5
# 11         49.0      NaN        Jai   Jaipur Pink Panthers        3
# 12         49.0      NaN        UPY            U.P. Yoddha       30
# 13         49.0      NaN         TT        Tamil Thalaivas       29
# 14         49.0      NaN        Kol        Bengal Warriors        4
# 15         49.0      NaN        Jai   Jaipur Pink Panthers        3
# 16         49.0      NaN        Del      Dabang Delhi K.C.        2
# 17         49.0      NaN        Ben        Bengaluru Bulls        1
# 18         49.0      NaN        Pun          Puneri Paltan        7
# 19         49.0      NaN        Mum                U Mumba        5
# 20         49.0      NaN        Hyd          Telugu Titans        8
# 21         49.0      NaN        Mum                U Mumba        5
# 22         49.0      NaN        Hyd          Telugu Titans        8
# 23         49.0      NaN        Jai   Jaipur Pink Panthers        3
# 24         49.0      NaN        Hyd          Telugu Titans        8
# 25         49.0      NaN         TT        Tamil Thalaivas       29
# 26         49.0      NaN         HS       Haryana Steelers       28
# 27         49.0      NaN        Pat          Patna Pirates        6
# 28         49.0      NaN         TT        Tamil Thalaivas       29
# 29         49.0      NaN        Jai   Jaipur Pink Panthers        3
# ...         ...      ...        ...                    ...      ...
# 6803        1.0     73.0        Kol                    NaN        4
# 6804        1.0     13.0        Del                    NaN        2
# 6805        1.0     41.0        Jai                    NaN        3
# 6806        1.0     32.0        Kol                    NaN        4
# 6807        1.0     43.0        Hyd                    NaN        8
# 6808        1.0     44.0        Hyd                    NaN        8
# 6809        1.0     70.0        Pat                    NaN        6
# 6810        1.0     27.0        Jai                    NaN        3
# 6811        1.0     30.0        Pun                    NaN        7
# 6812        1.0     65.0        Mum                    NaN        5
# 6813        1.0     37.0        Del                    NaN        2
# 6814        1.0     71.0        Kol                    NaN        4
# 6815        1.0     19.0        Jai                    NaN        3
# 6816        1.0     35.0        Kol                    NaN        4
# 6817        1.0     31.0        Hyd                    NaN        8
# 6818        1.0     55.0        Hyd                    NaN        8
# 6819        1.0     13.0        Ben                    NaN        1
# 6820        1.0     51.0        Jai                    NaN        3
# 6821        1.0     30.0        Pat                    NaN        6
# 6822        1.0     79.0        Jai                    NaN        3
# 6823        1.0     16.0        Hyd                    NaN        8
# 6824        1.0     21.0        Del                    NaN        2
# 6825        1.0     64.0        Ben                    NaN        1
# 6826        1.0     13.0   Ben, Pat                    NaN        6
# 6827        1.0      1.0        Kol                    NaN        4
# 6828        1.0      9.0        Pat                    NaN        6
# 6829        1.0     18.0        Jai                    NaN        3
# 6830        1.0     25.0   Ben, Del                    NaN        2
# 6831        1.0     14.0   Ben, Pat                    NaN        6
# 6832        1.0     50.0        Jai                    NaN        3
#
#       team_name  value
# 0           Pat   10.0
# 1            HS    5.0
# 2           Kol    5.0
# 3           Ben    5.0
# 4            HS    5.0
# 5           Pun    4.0
# 6           GFG    3.0
# 7           Del    3.0
# 8           Kol    3.0
# 9           Kol    3.0
# 10          Mum    2.0
# 11          Jai    2.0
# 12          UPY    2.0
# 13           TT    2.0
# 14          Kol    2.0
# 15          Jai    2.0
# 16          Del    2.0
# 17          Ben    2.0
# 18          Pun    2.0
# 19          Mum    2.0
# 20          Hyd    2.0
# 21          Mum    2.0
# 22          Hyd    1.0
# 23          Jai    1.0
# 24          Hyd    1.0
# 25           TT    1.0
# 26           HS    1.0
# 27          Pat    1.0
# 28           TT    1.0
# 29          Jai    1.0
# ...         ...    ...
# 6803        Kol    2.0
# 6804        Del    2.0
# 6805        Jai    2.0
# 6806        Kol    2.0
# 6807        Hyd    1.0
# 6808        Hyd    1.0
# 6809        Pat    1.0
# 6810        Jai    1.0
# 6811        Pun    1.0
# 6812        Mum    1.0
# 6813        Del    1.0
# 6814        Kol    1.0
# 6815        Jai    1.0
# 6816        Kol    1.0
# 6817        Hyd    1.0
# 6818        Hyd    1.0
# 6819        Ben    1.0
# 6820        Jai    1.0
# 6821        Pat    1.0
# 6822        Jai    1.0
# 6823        Hyd    1.0
# 6824        Del    1.0
# 6825        Ben    1.0
# 6826   Ben, Pat    1.0
# 6827        Kol    1.0
# 6828        Pat    1.0
# 6829        Jai    1.0
# 6830   Ben, Del    1.0
# 6831   Ben, Pat    1.0
# 6832        Jai    1.0
#
# [6833 rows x 17 columns]
